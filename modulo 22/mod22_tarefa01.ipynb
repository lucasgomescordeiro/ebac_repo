# %% [markdown]
# # Tarefa 01
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os monitores
# - Divirta-se :)

# %% [markdown]
# #### 1. Baixando dados de ativos
#     1. Baixe os dados de três ativos da sua escolha do Yahoo Finance, correspondente a um período de pelo menos 2 anos até a data mais recente.
#     2. Salve esses dados para que você possa utilizá-los na próxima tarefa.

# %%
from pandas_datareader import data as web

import plotly.express as px
from plotly import graph_objects

from datetime import datetime

import yfinance as yf
import pandas as pd
import numpy as np

# %%
# %%time
ativos = ['ITUB', 'PETR4.SA', 'VALE']
dt_ini = '2021-01-01'
dados = yf.download(ativos, start=dt_ini)
dados.head(2)
# Out:
# [*********************100%%**********************]  3 of 3 completed
# CPU times: total: 1.58 s
# Wall time: 1.25 s
#            Adj Close                           Close                        \
#                 ITUB   PETR4.SA       VALE      ITUB   PETR4.SA       VALE
# Date
# 2021-01-04  4.157610  11.359624  12.325172  4.855730  28.910000  17.400000
# 2021-01-05  4.129375  11.803634  12.530591  4.822754  30.040001  17.690001
#
#                 High                           Low                        \
#                 ITUB PETR4.SA       VALE      ITUB   PETR4.SA       VALE
# Date
# 2021-01-04  5.053586    29.18  17.700001  4.830998  28.530001  17.200001
# 2021-01-05  4.863974    30.18  17.700001  4.699093  28.240000  17.090000
#
#                 Open                      Volume
#                 ITUB PETR4.SA   VALE        ITUB    PETR4.SA        VALE
# Date
# 2021-01-04  5.037098    28.65  17.50  39295014.0  74719700.0  44854800.0
# 2021-01-05  4.723825    28.90  17.15  44530322.0  95181100.0  38460700.0

# %% [markdown]
# #### 2. Observando a volatilidade dentro do dia
# 1. Calcule a amplitude de variação do valor do ativo dentro do dia. Essa amplitude você pode calcular com um comando simples de adicionar uma coluna no Pandas: (valor máximo - valor mínimo).
# 2. Monte um gráfico de linha mostrando a variação dessa amplitude ao longo do período coletado, por ativo.
# 3. Veja se consegue identificar que ativo apresentou maior volatilidade.

# %% [markdown]
# ## 1. Calcule a amplitude de variação do valor do ativo dentro do dia. Essa amplitude você pode calcular com um comando simples de adicionar uma coluna no Pandas: (valor máximo - valor mínimo).

# %%
dados = dados.stack()

# %%
dados['amplitude'] = dados['High'] - dados['Low']
dados = dados.unstack()
dados['amplitude']
# Out:
#                 ITUB  PETR4.SA      VALE
# Date
# 2021-01-04  0.222588  0.650000  0.500000
# 2021-01-05  0.164881  1.940001  0.610001
# 2021-01-06  0.197856  0.850000  0.660000
# 2021-01-07  0.123660  0.809999  0.719999
# 2021-01-08  0.131904  1.410000  0.430000
# ...              ...       ...       ...
# 2024-03-12  0.110000  1.070000  0.340000
# 2024-03-13  0.150000  1.020000  0.260000
# 2024-03-14  0.120000  0.769997  0.210000
# 2024-03-15  0.090000  0.510002  0.160000
# 2024-03-18  0.150000  0.000000  0.160000
#
# [828 rows x 3 columns]

# %%
df_amplitude = dados['amplitude'].stack().reset_index()
df_amplitude.columns = ['data', 'ativo', 'amplitude']
df_amplitude
# Out:
#            data     ativo  amplitude
# 0    2021-01-04      ITUB   0.222588
# 1    2021-01-04  PETR4.SA   0.650000
# 2    2021-01-04      VALE   0.500000
# 3    2021-01-05      ITUB   0.164881
# 4    2021-01-05  PETR4.SA   1.940001
# ...         ...       ...        ...
# 2405 2024-03-15  PETR4.SA   0.510002
# 2406 2024-03-15      VALE   0.160000
# 2407 2024-03-18      ITUB   0.150000
# 2408 2024-03-18  PETR4.SA   0.000000
# 2409 2024-03-18      VALE   0.160000
#
# [2410 rows x 3 columns]

# %% [markdown]
# ## 2. Monte um gráfico de linha mostrando a variação dessa amplitude ao longo do período coletado, por ativo.

# %%
px.line(df_amplitude, x='data', y='amplitude', color='ativo', template='none')
# Out:
# <div>                            <div id="9fdb22c3-605a-4a48-9678-a1a886534d69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9fdb22c3-605a-4a48-9678-a1a886534d69")) {                    Plotly.newPlot(                        "9fdb22c3-605a-4a48-9678-a1a886534d69",                        [{"hovertemplate":"ativo=ITUB<br>data=%{x}<br>amplitude=%{y}<extra></extra>","legendgroup":"ITUB","line":{"color":"#1F77B4","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"ITUB","showlegend":true,"x":["2021-01-04T00:00:00","2021-01-05T00:00:00","2021-01-06T00:00:00","2021-01-07T00:00:00","2021-01-08T00:00:00","2021-01-11T00:00:00","2021-01-12T00:00:00","2021-01-13T00:00:00","2021-01-14T00:00:00","2021-01-15T00:00:00","2021-01-19T00:00:00","2021-01-20T00:00:00","2021-01-21T00:00:00","2021-01-22T00:00:00","2021-01-25T00:00:00","2021-01-26T00:00:00","2021-01-27T00:00:00","2021-01-28T00:00:00","2021-01-29T00:00:00","2021-02-01T00:00:00","2021-02-02T00:00:00","2021-02-03T00:00:00","2021-02-04T00:00:00","2021-02-05T00:00:00","2021-02-08T00:00:00","2021-02-09T00:00:00","2021-02-10T00:00:00","2021-02-11T00:00:00","2021-02-12T00:00:00","2021-02-16T00:00:00","2021-02-17T00:00:00","2021-02-18T00:00:00","2021-02-19T00:00:00","2021-02-22T00:00:00","2021-02-23T00:00:00","2021-02-24T00:00:00","2021-02-25T00:00:00","2021-02-26T00:00:00","2021-03-01T00:00:00","2021-03-02T00:00:00","2021-03-03T00:00:00","2021-03-04T00:00:00","2021-03-05T00:00:00","2021-03-08T00:00:00","2021-03-09T00:00:00","2021-03-10T00:00:00","2021-03-11T00:00:00","2021-03-12T00:00:00","2021-03-15T00:00:00","2021-03-16T00:00:00","2021-03-17T00:00:00","2021-03-18T00:00:00","2021-03-19T00:00:00","2021-03-22T00:00:00","2021-03-23T00:00:00","2021-03-24T00:00:00","2021-03-25T00:00:00","2021-03-26T00:00:00","2021-03-29T00:00:00","2021-03-30T00:00:00","2021-03-31T00:00:00","2021-04-01T00:00:00","2021-04-05T00:00:00","2021-04-06T00:00:00","2021-04-07T00:00:00","2021-04-08T00:00:00","2021-04-09T00:00:00","2021-04-12T00:00:00","2021-04-13T00:00:00","2021-04-14T00:00:00","2021-04-15T00:00:00","2021-04-16T00:00:00","2021-04-19T00:00:00","2021-04-20T00:00:00","2021-04-21T00:00:00","2021-04-22T00:00:00","2021-04-23T00:00:00","2021-04-26T00:00:00","2021-04-27T00:00:00","2021-04-28T00:00:00","2021-04-29T00:00:00","2021-04-30T00:00:00","2021-05-03T00:00:00","2021-05-04T00:00:00","2021-05-05T00:00:00","2021-05-06T00:00:00","2021-05-07T00:00:00","2021-05-10T00:00:00","2021-05-11T00:00:00","2021-05-12T00:00:00","2021-05-13T00:00:00","2021-05-14T00:00:00","2021-05-17T00:00:00","2021-05-18T00:00:00","2021-05-19T00:00:00","2021-05-20T00:00:00","2021-05-21T00:00:00","2021-05-24T00:00:00","2021-05-25T00:00:00","2021-05-26T00:00:00","2021-05-27T00:00:00","2021-05-28T00:00:00","2021-06-01T00:00:00","2021-06-02T00:00:00","2021-06-03T00:00:00","2021-06-04T00:00:00","2021-06-07T00:00:00","2021-06-08T00:00:00","2021-06-09T00:00:00","2021-06-10T00:00:00","2021-06-11T00:00:00","2021-06-14T00:00:00","2021-06-15T00:00:00","2021-06-16T00:00:00","2021-06-17T00:00:00","2021-06-18T00:00:00","2021-06-21T00:00:00","2021-06-22T00:00:00","2021-06-23T00:00:00","2021-06-24T00:00:00","2021-06-25T00:00:00","2021-06-28T00:00:00","2021-06-29T00:00:00","2021-06-30T00:00:00","2021-07-01T00:00:00","2021-07-02T00:00:00","2021-07-06T00:00:00","2021-07-07T00:00:00","2021-07-08T00:00:00","2021-07-09T00:00:00","2021-07-12T00:00:00","2021-07-13T00:00:00","2021-07-14T00:00:00","2021-07-15T00:00:00","2021-07-16T00:00:00","2021-07-19T00:00:00","2021-07-20T00:00:00","2021-07-21T00:00:00","2021-07-22T00:00:00","2021-07-23T00:00:00","2021-07-26T00:00:00","2021-07-27T00:00:00","2021-07-28T00:00:00","2021-07-29T00:00:00","2021-07-30T00:00:00","2021-08-02T00:00:00","2021-08-03T00:00:00","2021-08-04T00: ...

# %% [markdown]
# ## 3. Veja se consegue identificar que ativo apresentou maior volatilidade.

# %% [markdown]
# #### Entre os ativos selecionados o que apresentou maior volatilidade  em todo o periodo foi o ativo PETR4.SA com uma amplitude maxixma de 3.10 em 28 de fevereiro de 2024
