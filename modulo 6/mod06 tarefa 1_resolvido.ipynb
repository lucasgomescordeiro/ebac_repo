# %% [markdown]
# # Módulo 6 tarefa 1
#
# #### 1) A base 'sinasc_RO_2019.csv' contém dados do sistema de nascidos vivos do DataSUS, cujo dicionário de dados está no arquivo 'Estrutura_SINASC_para_CD.pdf'. Carregue esses arquivos.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('b1abb33c4f.csv')
df2 = df.loc[:, ['APGAR1', 'APGAR5', 'SEXO', 'GESTACAO', 'ESTCIVMAE', 'CONSULTAS']]
amostras = df2.sample(10)
amostras.head()
# Out:
#        APGAR1  APGAR5       SEXO           GESTACAO  ESTCIVMAE  CONSULTAS
# 16358     8.0     9.0   Feminino    37 a 41 semanas        2.0          4
# 19167     8.0     9.0  Masculino  42 semanas e mais        5.0          4
# 8229      8.0     9.0   Feminino    37 a 41 semanas        1.0          3
# 7054      9.0     9.0  Masculino    37 a 41 semanas        NaN          4
# 17366     8.0     9.0  Masculino    37 a 41 semanas        2.0          4

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=27028, step=1)

# %% [markdown]
# ####  2) Monte um gráficos de barras com as variáveis APGAR1, APGAR5, SEXO, GESTACAO, ESTCIVMAE.

# %%
fig, axs = plt.subplots(2,3)

amostras['APGAR1'].plot.bar(ax=axs[0][0])
amostras['APGAR5'].plot.bar(ax=axs[0][1])
amostras['SEXO'].value_counts().plot.bar(ax=axs[0][2])
amostras['GESTACAO'].value_counts().plot.bar(ax=axs[1][0])
amostras['ESTCIVMAE'].value_counts().plot.bar(ax=axs[1][1])
plt.subplots_adjust(hspace=0.8, wspace=0.4)

# %% [markdown]
# #### 3) Monte um gráfico de barras mostrando o APGAR5 médio por CONSULTAS

# %%
media = amostras.groupby('CONSULTAS')['APGAR5'].mean()

media_plot = media.reset_index()

media_plot.columns = ['CONSULTAS', 'APGAR5_medio']

sns.barplot(x='CONSULTAS', y='APGAR5_medio', data=df_plot)
# Out:
# <AxesSubplot:xlabel='CONSULTAS', ylabel='APGAR5_medio'>

# %% [markdown]
# ####  4) Monte um painel com 4 gráficos mostrando as frequencias de SEXO, GESTACAO, ESTCIVMAE e CONSULTAS

# %%
fig, axs = plt.subplots(2,2)

df['SEXO'].value_counts().plot.bar(ax=axs[0][0])
df['GESTACAO'].value_counts().plot.bar(ax=axs[0][1])
df['ESTCIVMAE'].value_counts().plot.bar(ax=axs[1][0])
df['CONSULTAS'].value_counts().plot.bar(ax=axs[1][1])
plt.subplots_adjust(hspace=1.5, wspace=0.4)

# %%
sdgfb
